# %% [markdown]
# MCAO

# %% [markdown]
# Subject: 20210408 Rat

# %% [markdown]
# Data: ABP vs Brain PPG

# %% [markdown]
# Method: TFA

# %% [markdown]
# Time: pre, MCAO, MCAO1h, MCAO2h, post, post1d, post2d, post3d

# %%
import scipy.io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import sys
sys.path.append("../../../tfa_car/")
from tfa_car import tfa_car

# %%
class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

# %%
params = []
params = dotdict(params)
params.plot = 1
params.vlf = [0.5, 2.1]
params.lf = [2.1, 6]
params.hf = [6, 15]
params.plot_f_range = [0.5, 15]

# %% [markdown]
# # pre

# %%
fs = 10000
preMCAO = scipy.io.loadmat('20210408/20210408_r1210a_preMCAO.mat')
preMCAO_df = pd.DataFrame(data = preMCAO["data"], columns= ["ECG", "ABP", "PPGL", "PPGR"])
tpreMCAO = np.arange(0, len(preMCAO_df))/fs
preMCAO_df['Time'] = tpreMCAO

# %% [markdown]
# ### pre - L

# %%
# plt.figure(figsize=(20,5))
# t1 = 1550
# t2 = t1 + 300
# preMCAO_df_1 = preMCAO_df[(preMCAO_df['Time'] > t1) & (preMCAO_df['Time'] < t2)]
# plt.plot(preMCAO_df_1['Time'], preMCAO_df_1["ABP"]-80)
# plt.plot(preMCAO_df_1['Time'], preMCAO_df_1["PPGL"]/100)
# plt.show()
# # All
# plt.figure(figsize=(20,5))
# plt.plot(preMCAO_df['Time'], preMCAO_df["ABP"]-80)
# plt.plot(preMCAO_df['Time'], preMCAO_df["PPGR"]/100)
# plt.show()

# %%
preMCAO_L = tfa_car(preMCAO_df["ABP"], preMCAO_df["PPGL"], fs, params)

# %% [markdown]
# ### pre - R

# %%
preMCAO_R = tfa_car(preMCAO_df["ABP"], preMCAO_df["PPGR"], fs, params)

# %% [markdown]
# # MCAO

# %%
fs = 10000
MCAO = scipy.io.loadmat('20210408/20210408_r1210a_MCAO.mat')
MCAO_df = pd.DataFrame(data = MCAO["data"], columns= ["ECG", "ABP", "PPGL", "PPGR"])
tMCAO = np.arange(0, len(MCAO_df))/fs
MCAO_df['Time'] = tMCAO

# %% [markdown]
# ### MCAO - L

# %%
# plt.figure(figsize=(20,5))
# t1 = 1000
# t2 = t1 + 300
# MCAO_df_1 = MCAO_df[(MCAO_df['Time'] > t1) & (MCAO_df['Time'] < t2)]
# plt.plot(MCAO_df_1['Time'], MCAO_df_1["ABP"]-40)
# plt.plot(MCAO_df_1['Time'], MCAO_df_1["PPGL"]/100)
# plt.show()
# All
# plt.figure(figsize=(20,5))
# plt.plot(MCAO_df['Time'], MCAO_df["ABP"]-40)
# plt.plot(MCAO_df['Time'], MCAO_df["PPGR"]/100)
# plt.show()

# %%
MCAO_L = tfa_car(MCAO_df["ABP"], MCAO_df["PPGL"], fs, params)

# %% [markdown]
# ### MCAO - R

# %%
# plt.figure(figsize=(20,5))
# t1 = 1000
# t2 = t1 + 300
# MCAO_df_1 = MCAO_df[(MCAO_df['Time'] > t1) & (MCAO_df['Time'] < t2)]
# plt.plot(MCAO_df_1['Time'], MCAO_df_1["ABP"]-40)
# plt.plot(MCAO_df_1['Time'], MCAO_df_1["PPGR"]/100)
# plt.show()
# All
# plt.figure(figsize=(20,5))
# plt.plot(MCAO_df['Time'], MCAO_df["ABP"]-40)
# plt.plot(MCAO_df['Time'], MCAO_df["PPGR"]/100)
# plt.show()

# %%
MCAO_R = tfa_car(MCAO_df["ABP"], MCAO_df["PPGR"], fs, params)

# %% [markdown]
# # MCAO1h

# %%
fs = 10000
MCAO1h = scipy.io.loadmat('20210408/20210408_r1210a_MCAO1h.mat')
MCAO1h_df = pd.DataFrame(data = MCAO1h["data"], columns= ["ECG", "ABP", "PPGL", "PPGR"])
tMCAO1h = np.arange(0, len(MCAO1h_df))/fs
MCAO1h_df['Time'] = tMCAO1h

# %% [markdown]
# ### MCAO1h - L

# %%
# plt.figure(figsize=(20,5))
# t1 = 1000
# t2 = t1 + 300
# MCAO1h_df_1 = MCAO1h_df[(MCAO1h_df['Time'] > t1) & (MCAO1h_df['Time'] < t2)]
# plt.plot(MCAO1h_df_1['Time'], MCAO1h_df_1["ABP"]-40)
# plt.plot(MCAO1h_df_1['Time'], MCAO1h_df_1["PPGL"]/100)
# plt.show()
# All
# plt.figure(figsize=(20,5))
# plt.plot(MCAO1h_df['Time'], MCAO1h_df["ABP"]-40)
# plt.plot(MCAO1h_df['Time'], MCAO1h_df["PPGR"]/100)
# plt.show()

# %%
MCAO1h_L = tfa_car(MCAO1h_df["ABP"], MCAO1h_df["PPGL"], fs, params)

# %% [markdown]
# ### MCAO1h - R

# %%
# plt.figure(figsize=(20,5))
# t1 = 1000
# t2 = t1 + 300
# MCAO1h_df_1 = MCAO1h_df[(MCAO1h_df['Time'] > t1) & (MCAO1h_df['Time'] < t2)]
# plt.plot(MCAO1h_df_1['Time'], MCAO1h_df_1["ABP"]-40)
# plt.plot(MCAO1h_df_1['Time'], MCAO1h_df_1["PPGR"]/100)
# plt.show()
# All
# plt.figure(figsize=(20,5))
# plt.plot(MCAO1h_df['Time'], MCAO1h_df["ABP"]-40)
# plt.plot(MCAO1h_df['Time'], MCAO1h_df["PPGR"]/100)
# plt.show()

# %%
MCAO1h_R = tfa_car(MCAO1h_df["ABP"], MCAO1h_df["PPGR"], fs, params)

# %% [markdown]
# # MCAO2h

# %%
fs = 10000
MCAO2h = scipy.io.loadmat('20210408/20210408_r1210a_MCAO2h.mat')
MCAO2h_df = pd.DataFrame(data = MCAO2h["data"], columns= ["ECG", "ABP", "PPGL", "PPGR"])
tMCAO2h = np.arange(0, len(MCAO2h_df))/fs
MCAO2h_df['Time'] = tMCAO2h

# %% [markdown]
# ### MCAO2h - L

# %%
# plt.figure(figsize=(20,5))
# t1 = 1000
# t2 = t1 + 300
# MCAO2h_df_1 = MCAO2h_df[(MCAO2h_df['Time'] > t1) & (MCAO2h_df['Time'] < t2)]
# plt.plot(MCAO2h_df_1['Time'], MCAO2h_df_1["ABP"]-40)
# plt.plot(MCAO2h_df_1['Time'], MCAO2h_df_1["PPGL"]/100)
# plt.show()
# All
# plt.figure(figsize=(20,5))
# plt.plot(MCAO2h_df['Time'], MCAO2h_df["ABP"]-40)
# plt.plot(MCAO2h_df['Time'], MCAO2h_df["PPGR"]/100)
# plt.show()

# %%
MCAO2h_L = tfa_car(MCAO2h_df["ABP"], MCAO2h_df["PPGL"], fs, params)

# %% [markdown]
# ### MCAO2h - R

# %%
# plt.figure(figsize=(20,5))
# t1 = 1000
# t2 = t1 + 300
# MCAO2h_df_1 = MCAO2h_df[(MCAO2h_df['Time'] > t1) & (MCAO2h_df['Time'] < t2)]
# plt.plot(MCAO2h_df_1['Time'], MCAO2h_df_1["ABP"]-40)
# plt.plot(MCAO2h_df_1['Time'], MCAO2h_df_1["PPGR"]/100)
# plt.show()
# All
# plt.figure(figsize=(20,5))
# plt.plot(MCAO2h_df['Time'], MCAO2h_df["ABP"]-40)
# plt.plot(MCAO2h_df['Time'], MCAO2h_df["PPGR"]/100)
# plt.show()

# %%
MCAO2h_R = tfa_car(MCAO2h_df["ABP"], MCAO2h_df["PPGR"], fs, params)

# %% [markdown]
# # postMCAO

# %%
fs = 10000
postMCAO = scipy.io.loadmat('20210408/20210408_r1210a_postMCAO.mat')
postMCAO_df = pd.DataFrame(data = postMCAO["data"], columns= ["ECG", "ABP", "PPGL", "PPGR"])
tpostMCAO = np.arange(0, len(postMCAO_df))/fs
postMCAO_df['Time'] = tpostMCAO

# %% [markdown]
# ### postMCAO - L

# %%
# plt.figure(figsize=(20,5))
# t1 = 1100
# t2 = t1 + 300
# postMCAO_df_1 = postMCAO_df[(postMCAO_df['Time'] > t1) & (postMCAO_df['Time'] < t2)]
# plt.plot(postMCAO_df_1['Time'], postMCAO_df_1["ABP"]-70)
# plt.plot(postMCAO_df_1['Time'], postMCAO_df_1["PPGL"]/1000)
# plt.show()
# # All
# plt.figure(figsize=(20,5))
# plt.plot(postMCAO_df['Time'], postMCAO_df["ABP"]-70)
# plt.plot(postMCAO_df['Time'], postMCAO_df["PPGR"]/1000)
# plt.show()

# %%
postMCAO_L = tfa_car(postMCAO_df["ABP"], postMCAO_df["PPGL"], fs, params)

# %% [markdown]
# ### postMCAO - R

# %%
postMCAO_R = tfa_car(postMCAO_df["ABP"], postMCAO_df["PPGR"], fs, params)

# %% [markdown]
# # postMCAO1d

# %%
fs = 10000
postMCAO1d = scipy.io.loadmat('20210408/20210408_r1210a_postMCAO1d.mat')
postMCAO1d_df = pd.DataFrame(data = postMCAO1d["data"], columns= ["ECG", "ABP", "PPGL", "PPGR"])
tpostMCAO1d = np.arange(0, len(postMCAO1d_df))/fs
postMCAO1d_df['Time'] = tpostMCAO1d

# %% [markdown]
# ### postMCAO1d - L

# %%
plt.figure(figsize=(20,5))
t1 = 40
t2 = t1 + 10 
postMCAO1d_df_1 = postMCAO1d_df[(postMCAO1d_df['Time'] > t1) & (postMCAO1d_df['Time'] < t2)]
plt.plot(postMCAO1d_df_1['Time'], postMCAO1d_df_1["ABP"]-92)
plt.plot(postMCAO1d_df_1['Time'], postMCAO1d_df_1["PPGL"]/1000)
plt.show()
# All
plt.figure(figsize=(20,5))
plt.plot(postMCAO1d_df['Time'], postMCAO1d_df["ABP"]-90)
plt.plot(postMCAO1d_df['Time'], postMCAO1d_df["PPGR"]/1000)
plt.show()

# %%
postMCAO1d_L = tfa_car(postMCAO1d_df["ABP"], postMCAO1d_df["PPGL"], fs, params)

# %% [markdown]
# ### postMCAO1d - R

# %%
postMCAO1d_R = tfa_car(postMCAO1d_df["ABP"], postMCAO1d_df["PPGR"], fs, params)

# %% [markdown]
# # postMCAO2d

# %%
fs = 10000
postMCAO2d = scipy.io.loadmat('20210408/20210408_r1210a_postMCAO2d.mat')
postMCAO2d_df = pd.DataFrame(data = postMCAO2d["data"], columns= ["ECG", "ABP", "PPGL", "PPGR"])
tpostMCAO2d = np.arange(0, len(postMCAO2d_df))/fs
postMCAO2d_df['Time'] = tpostMCAO2d

# %% [markdown]
# ### postMCAO2d - L

# %%
# plt.figure(figsize=(20,5))
# t1 = 1100
# t2 = t1 + 300
# postMCAO2d_df_1 = postMCAO2d_df[(postMCAO2d_df['Time'] > t1) & (postMCAO2d_df['Time'] < t2)]
# plt.plot(postMCAO2d_df_1['Time'], postMCAO2d_df_1["ABP"]-70)
# plt.plot(postMCAO2d_df_1['Time'], postMCAO2d_df_1["PPGL"]/1000)
# plt.show()
# # All
# plt.figure(figsize=(20,5))
# plt.plot(postMCAO2d_df['Time'], postMCAO2d_df["ABP"]-70)
# plt.plot(postMCAO2d_df['Time'], postMCAO2d_df["PPGR"]/1000)
# plt.show()

# %%
postMCAO2d_L = tfa_car(postMCAO2d_df["ABP"], postMCAO2d_df["PPGL"], fs, params)

# %% [markdown]
# ### postMCAO2d - R

# %%
postMCAO2d_R = tfa_car(postMCAO2d_df["ABP"], postMCAO2d_df["PPGR"], fs, params)

# %% [markdown]
# # postMCAO3d

# %%
fs = 10000
postMCAO3d = scipy.io.loadmat('20210408/20210408_r1210a_postMCAO3d.mat')
postMCAO3d_df = pd.DataFrame(data = postMCAO3d["data"], columns= ["ECG", "ABP", "PPGL", "PPGR"])
tpostMCAO3d = np.arange(0, len(postMCAO3d_df))/fs
postMCAO3d_df['Time'] = tpostMCAO3d

# %% [markdown]
# ### postMCAO3d - L

# %%
# plt.figure(figsize=(20,5))
# t1 = 1100
# t2 = t1 + 300
# postMCAO3d_df_1 = postMCAO3d_df[(postMCAO3d_df['Time'] > t1) & (postMCAO3d_df['Time'] < t2)]
# plt.plot(postMCAO3d_df_1['Time'], postMCAO3d_df_1["ABP"]-70)
# plt.plot(postMCAO3d_df_1['Time'], postMCAO3d_df_1["PPGL"]/1000)
# plt.show()
# # All
# plt.figure(figsize=(20,5))
# plt.plot(postMCAO3d_df['Time'], postMCAO3d_df["ABP"]-70)
# plt.plot(postMCAO3d_df['Time'], postMCAO3d_df["PPGL"]/1000)
# plt.show()

# %%
postMCAO3d_L = tfa_car(postMCAO3d_df["ABP"], postMCAO3d_df["PPGL"], fs, params)

# %% [markdown]
# ### postMCAO3d - R

# %%
postMCAO3d_R = tfa_car(postMCAO3d_df["ABP"], postMCAO3d_df["PPGR"], fs, params)

# %% [markdown]
# -------------------

# %% [markdown]
# # Statistic

# %%
print("Coherence - VLF")
print("pre_L:", preMCAO_L.Coh2_vlf, "pre_R", preMCAO_R.Coh2_vlf)
print("MCAO_L:", MCAO_L.Coh2_vlf, "MCAO_L", MCAO_R.Coh2_vlf)
print("MCAO1h_L:", MCAO1h_L.Coh2_vlf, "MCAO1h_L", MCAO1h_R.Coh2_vlf)
print("MCAO2h_L:", MCAO2h_L.Coh2_vlf, "MCAO2h_L", MCAO2h_R.Coh2_vlf)
print("postMCAO_L:", postMCAO_L.Coh2_vlf, "postMCAO_R", postMCAO_R.Coh2_vlf)
print("postMCAO1d_L:", postMCAO1d_L.Coh2_vlf, "postMCAO1d_R", postMCAO1d_R.Coh2_vlf)
print("postMCAO2d_L:", postMCAO2d_L.Coh2_vlf, "postMCAO2d_R", postMCAO2d_R.Coh2_vlf)
print("postMCAO3d_L:", postMCAO3d_L.Coh2_vlf, "postMCAO3d_R", postMCAO3d_R.Coh2_vlf)
# Out:
# Coherence - VLF
# pre_L: 0.3978902130421079 pre_R 0.4066458005387492
# MCAO_L: 0.38137545210645757 MCAO_L 0.37577169195008553
# MCAO1h_L: 0.400350652378202 MCAO1h_L 0.39748113167377846
# MCAO2h_L: 0.44752242100222317 MCAO2h_L 0.3758795648642833
# postMCAO_L: 0.6073125337098327 postMCAO_R 0.46120827966413785
# postMCAO1d_L: 0.010788167827787 postMCAO1d_R 0.010240517880707987
# postMCAO2d_L: 0.17223806955251203 postMCAO2d_R 0.12697669442503484
# postMCAO3d_L: 0.018263088537652582 postMCAO3d_R 0.11666809824962929

# %%
print("Coherence - LF")
print("pre_L:", preMCAO_L.Coh2_lf, "pre_R", preMCAO_R.Coh2_lf)
print("in_L:", MCAO_L.Coh2_lf, "in_R", MCAO_R.Coh2_lf)
print("pos_L:", postMCAO_L.Coh2_lf, "pos_R", postMCAO_R.Coh2_lf)
# Out:
# Coherence - LF
# pre_L: 0.35486480128377235 pre_R 0.41776437115753023
# in_L: 0.3947790008419813 in_R 0.4309068993131184
# pos_L: 0.7855547061786635 pos_R 0.7661041565184811

# %%
print("Coherence - HF")
print("pre_L:", preMCAO_L.Coh2_hf, "pre_R", preMCAO_R.Coh2_hf)
print("in_L:", MCAO_L.Coh2_hf, "in_R", MCAO_R.Coh2_hf)
print("pos_L:", postMCAO_L.Coh2_hf, "pos_R", postMCAO_R.Coh2_hf)
# Out:
# Coherence - HF
# pre_L: 0.15209177094293105 pre_R 0.22381442918034364
# in_L: 0.1477338877387351 in_R 0.21787023226200877
# pos_L: 0.144014417501346 pos_R 0.17444134727962404

# %%
# Coherence
# plt.style.use('ggplot')
labels = ['Left', 'Right']

pre = [preMCAO_L.Coh2_vlf, preMCAO_R.Coh2_vlf]
MCAO = [MCAO_L.Coh2_vlf, MCAO_R.Coh2_vlf]
MCAO1h = [MCAO1h_L.Coh2_vlf, MCAO1h_R.Coh2_vlf]
MCAO2h = [MCAO2h_L.Coh2_vlf, MCAO2h_R.Coh2_vlf]
post = [postMCAO_L.Coh2_vlf, postMCAO_R.Coh2_vlf]
post1d = [postMCAO1d_L.Coh2_vlf, postMCAO1d_R.Coh2_vlf]
post2d = [postMCAO2d_L.Coh2_vlf, postMCAO2d_R.Coh2_vlf]
post3d = [postMCAO3d_L.Coh2_vlf, postMCAO3d_R.Coh2_vlf]

x = np.arange(len(labels))  # the label locations
width = 0.1  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width*3.5, pre, width, label='pre')
rects2 = ax.bar(x - width*2.5, MCAO, width, label='MCAO')
rects3 = ax.bar(x - width*1.5, MCAO1h, width, label='MCAO1h')
rects4 = ax.bar(x - width*0.5, MCAO2h, width, label='MCAO2h')
rects5 = ax.bar(x + width*0.5, post, width, label='post')
rects6 = ax.bar(x + width*1.5, post1d, width, label='post1d')
rects7 = ax.bar(x + width*2.5, post2d, width, label='post2d')
rects8 = ax.bar(x + width*3.5, post3d, width, label='post3d')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('$|Coh|^2$')
ax.set_title("Coherence_vlf")
ax.set_xticks(x)
ax.set_xticklabels(labels)
# ax.legend()
plt.show()

# %%
# Coherence
labels = ['Left', 'Right']

pre = [preMCAO_L.Coh2_vlf, preMCAO_R.Coh2_vlf]
MCAO = [(MCAO_L.Coh2_vlf + MCAO1h_L.Coh2_vlf + MCAO2h_L.Coh2_vlf)/3, (MCAO_R.Coh2_vlf + MCAO1h_R.Coh2_vlf + MCAO2h_R.Coh2_vlf)/3,]
post = [(postMCAO_L.Coh2_vlf + postMCAO1d_L.Coh2_vlf + postMCAO2d_L.Coh2_vlf + postMCAO3d_L.Coh2_vlf)/4, (postMCAO_R.Coh2_vlf + postMCAO1d_R.Coh2_vlf + postMCAO2d_R.Coh2_vlf + postMCAO3d_R.Coh2_vlf)/4] 
# exclude post
# post = [(postMCAO1d_L.Coh2_vlf + postMCAO2d_L.Coh2_vlf + postMCAO3d_L.Coh2_vlf)/3, (postMCAO1d_R.Coh2_vlf + postMCAO2d_R.Coh2_vlf + postMCAO3d_R.Coh2_vlf)/3] 

x = np.arange(len(labels))  # the label locations
width = 0.1  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, pre, width, label='pre')
rects2 = ax.bar(x, MCAO, width, label='MCAO')
rects3 = ax.bar(x + width, post, width, label='post')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('$|Coh|^2$')
ax.set_title("Coherence_vlf")
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.show()

# %%
# Coherence
labels = ['Left', 'Right']

pre = [preMCAO_L.Coh2_lf, preMCAO_R.Coh2_lf]
MCAO = [MCAO_L.Coh2_lf, MCAO_R.Coh2_lf]
MCAO1h = [MCAO1h_L.Coh2_lf, MCAO1h_R.Coh2_lf]
MCAO2h = [MCAO2h_L.Coh2_lf, MCAO2h_R.Coh2_lf]
post = [postMCAO_L.Coh2_lf, postMCAO_R.Coh2_lf]
post1d = [postMCAO1d_L.Coh2_lf, postMCAO1d_R.Coh2_lf]
post2d = [postMCAO2d_L.Coh2_lf, postMCAO2d_R.Coh2_lf]
post3d = [postMCAO3d_L.Coh2_lf, postMCAO3d_R.Coh2_lf]

x = np.arange(len(labels))  # the label locations
width = 0.1  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width*3.5, pre, width, label='pre')
rects2 = ax.bar(x - width*2.5, MCAO, width, label='MCAO')
rects3 = ax.bar(x - width*1.5, MCAO1h, width, label='MCAO1h')
rects4 = ax.bar(x - width*0.5, MCAO2h, width, label='MCAO2h')
rects5 = ax.bar(x + width*0.5, post, width, label='post')
rects6 = ax.bar(x + width*1.5, post1d, width, label='post1d')
rects7 = ax.bar(x + width*2.5, post2d, width, label='post2d')
rects8 = ax.bar(x + width*3.5, post3d, width, label='post3d')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('$|Coh|^2$')
ax.set_title("Coherence_lf")
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.show()

# %%
# Coherence
labels = ['Left', 'Right']

pre = [preMCAO_L.Coh2_hf, preMCAO_R.Coh2_hf]
MCAO = [MCAO_L.Coh2_hf, MCAO_R.Coh2_hf]
MCAO1h = [MCAO1h_L.Coh2_hf, MCAO1h_R.Coh2_hf]
MCAO2h = [MCAO2h_L.Coh2_hf, MCAO2h_R.Coh2_hf]
post = [postMCAO_L.Coh2_hf, postMCAO_R.Coh2_hf]
post1d = [postMCAO1d_L.Coh2_hf, postMCAO1d_R.Coh2_hf]
post2d = [postMCAO2d_L.Coh2_hf, postMCAO2d_R.Coh2_hf]
post3d = [postMCAO3d_L.Coh2_hf, postMCAO3d_R.Coh2_hf]

x = np.arange(len(labels))  # the label locations
width = 0.1  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width*3.5, pre, width, label='pre')
rects2 = ax.bar(x - width*2.5, MCAO, width, label='MCAO')
rects3 = ax.bar(x - width*1.5, MCAO1h, width, label='MCAO1h')
rects4 = ax.bar(x - width*0.5, MCAO2h, width, label='MCAO2h')
rects5 = ax.bar(x + width*0.5, post, width, label='post')
rects6 = ax.bar(x + width*1.5, post1d, width, label='post1d')
rects7 = ax.bar(x + width*2.5, post2d, width, label='post2d')
rects8 = ax.bar(x + width*3.5, post3d, width, label='post3d')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('$|Coh|^2$')
ax.set_title("Coherence_hf")
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.show()
